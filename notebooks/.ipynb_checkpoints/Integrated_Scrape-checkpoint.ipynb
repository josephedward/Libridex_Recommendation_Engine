# %%
import pandas as pd
from bs4 import BeautifulSoup
import time 
from splinter import Browser
from textblob import TextBlob
import nltk
nltk.download('averaged_perceptron_tagger')
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
import re
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import random
from tqdm import tqdm
from gensim.models import Word2Vec 
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings;
# import untangle
# warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/dev/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
executable_path = {'executable_path':'../resources/chromedriver'}
browser = Browser('chrome', **executable_path)
test_url= 'https://librivox.org/api/feed/audiobooks/?id=47'
browser.visit(test_url)
test_page=browser.html
soup = BeautifulSoup(test_page, 'html.parser')
# print(soup)
author_fname= soup.find('author').find('first_name').get_text()
author_lname= soup.find('author').find('last_name').get_text()
author= author_fname+" "+author_lname
print(author)
# soup = BeautifulSoup(xml)
# look in the main node for object's with attr=name, optionally look up attrs with regex
# my_objects = soup.findAll("object", attrs={'attr':'name'})
# for my_object in my_objects:
#     this will print a list of the contents of the tag
#     print (my_object.contents)
# import untangle
# doc = untangle.parse(soup.find('body'))
# child_name = doc.root.child['name'] # 'child1'
# print(child_name)
# Out:
# Alexandre Dumas

# %%
executable_path = {'executable_path':'../resources/chromedriver'}
browser = Browser('chrome', **executable_path)
book_objs=[]
for x in range(16000):
    print("Searching Librivox ID: ",x)
    librivox_id_search = f'https://librivox.org/api/feed/audiobooks/?id={x}'
    # librivox_id_search = f'https://librivox.org/api/feed/audiobooks/?id=65'
    try:
            browser.visit(librivox_id_search)
            librivox_id_search_page = browser.html
            soup = BeautifulSoup(librivox_id_search_page, 'html.parser')
            lib_id=soup.find("id").get_text()
            title=soup.find("title").get_text()
            description=soup.find("description").get_text()
            language=soup.find("language").get_text()
            copyright_year=soup.find("copyright_year").get_text()
            lib_url=soup.find('url_librivox').get_text()
            author_fname= soup.find('author').find('first_name').get_text()
            author_lname= soup.find('author').find('last_name').get_text()
            author= author_fname+" "+author_lname
            browser.visit(lib_url)
            book_url_page=browser.html
            soup = BeautifulSoup(book_url_page, 'html.parser')
            genre=soup.find_all('p', class_='book-page-genre')[0].get_text()
            genre_arr=genre.split(":")
            genre=genre_arr[1]
            book_objs.append({"lib_id":lib_id,
                        "title":title,
                        "author":author,
                        "genre":genre,
                        "description":description,
                        "language":language,
                        "copyright_year":copyright_year,
                        "lib_url":lib_url                  
                            })
            pd.DataFrame(book_objs).to_csv("lbvx_book_list_072420")
    except: 
        print("couldn't locate")
# Out:
# Searching Librivox ID:  0
# Searching Librivox ID:  1
# couldn't locate
# Searching Librivox ID:  2
# couldn't locate
# Searching Librivox ID:  3
# couldn't locate
# Searching Librivox ID:  4
# couldn't locate
# Searching Librivox ID:  5
# couldn't locate
# Searching Librivox ID:  6
# couldn't locate
# Searching Librivox ID:  7
# couldn't locate
# Searching Librivox ID:  8
# couldn't locate
# Searching Librivox ID:  9
# couldn't locate
# Searching Librivox ID:  10
# couldn't locate
# Searching Librivox ID:  11
# couldn't locate
# Searching Librivox ID:  12
# couldn't locate
# Searching Librivox ID:  13
# couldn't locate
# Searching Librivox ID:  14
# couldn't locate
# Searching Librivox ID:  15
# couldn't locate
# Searching Librivox ID:  16
# couldn't locate
# Searching Librivox ID:  17
# couldn't locate
# Searching Librivox ID:  18
# couldn't locate
# Searching Librivox ID:  19
# couldn't locate
# Searching Librivox ID:  20
# couldn't locate
# Searching Librivox ID:  21
# couldn't locate
# Searching Librivox ID:  22
# couldn't locate
# Searching Librivox ID:  23
# couldn't locate
# Searching Librivox ID:  24
# couldn't locate
# Searching Librivox ID:  25
# couldn't locate
# Searching Librivox ID:  26
# couldn't locate
# Searching Librivox ID:  27
# couldn't locate
# Searching Librivox ID:  28
# couldn't locate
# Searching Librivox ID:  29
# couldn't locate
# Searching Librivox ID:  30
# couldn't locate
# Searching Librivox ID:  31
# couldn't locate
# Searching Librivox ID:  32
# couldn't locate
# Searching Librivox ID:  33
# couldn't locate
# Searching Librivox ID:  34
# couldn't locate
# Searching Librivox ID:  35
# couldn't locate
# Searching Librivox ID:  36
# couldn't locate
# Searching Librivox ID:  37
# couldn't locate
# Searching Librivox ID:  38
# couldn't locate
# Searching Librivox ID:  39
# couldn't locate
# Searching Librivox ID:  40
# couldn't locate
# Searching Librivox ID:  41
# couldn't locate
# Searching Librivox ID:  42
# couldn't locate
# Searching Librivox ID:  43
# couldn't locate
# Searching Librivox ID:  44
# couldn't locate
# Searching Librivox ID:  45
# couldn't locate
# Searching Librivox ID:  46
# couldn't locate
# Searching Librivox ID:  47
# Searching Librivox ID:  48
# couldn't locate
# Searching Librivox ID:  49
# couldn't locate
# Searching Librivox ID:  50
# couldn't locate
# Searching Librivox ID:  51
# couldn't locate
# Searching Librivox ID:  52
# Searching Librivox ID:  53
# Searching Librivox ID:  54
# Searching Librivox ID:  55
# Searching Librivox ID:  56
# Searching Librivox ID:  57
# Searching Librivox ID:  58
# couldn't locate
# Searching Librivox ID:  59
# Searching Librivox ID:  60
# couldn't locate
# Searching Librivox ID:  61
# couldn't locate
# Searching Librivox ID:  62
# couldn't locate
# Searching Librivox ID:  63
# couldn't locate
# Searching Librivox ID:  64
# Searching Librivox ID:  65
# Searching Librivox ID:  66
# Searching Librivox ID:  67
# Searching Librivox ID:  68
# Searching Librivox ID:  69
# couldn't locate
# Searching Librivox ID:  70
# couldn't locate
# Searching Librivox ID:  71
# Searching Librivox ID:  72
# couldn't locate
# Searching Librivox ID:  73
# Searching Librivox ID:  74
# Searching Librivox ID:  75
# Searching Librivox ID:  76
# Searching Librivox ID:  77
# couldn't locate
# Searching Librivox ID:  78
# Searching Librivox ID:  79
# Searching Librivox ID:  80
# Searching Librivox ID:  81
# Searching Librivox ID:  82
# Searching Librivox ID:  83
# Searching Librivox ID:  84
# Searching Librivox ID:  85
# Searching Librivox ID:  86
# Searching Librivox ID:  87
# couldn't locate
# Searching Librivox ID:  88
# Searching Librivox ID:  89
# Searching Librivox ID:  90
# Searching Librivox ID:  91
# couldn't locate
# Searching Librivox ID:  92
# couldn't locate
# Searching Librivox ID:  93
# Searching Librivox ID:  94
# Searching Librivox ID:  95
# couldn't locate
# Searching Librivox ID:  96
# Searching Librivox ID:  97
# Searching Librivox ID:  98
# couldn't locate
# Searching Librivox ID:  99
# Searching Librivox ID:  100
# Searching Librivox ID:  101
# couldn't locate
# Searching Librivox ID:  102
# couldn't locate
# Searching Librivox ID:  103
# couldn't locate
# Searching Librivox ID:  104
# Searching Librivox ID:  105
# Searching Librivox ID:  106
# Searching Librivox ID:  107
# couldn't locate
# Searching Librivox ID:  108
# couldn't locate
# Searching Librivox ID:  109
# couldn't locate
# Searching Librivox ID:  110
# couldn't locate
# Searching Librivox ID:  111
# couldn't locate
# Searching Librivox ID:  112
# couldn't locate
# Searching Librivox ID:  113
# couldn't locate
# Searching Librivox ID:  114
# couldn't locate
# Searching Librivox ID:  115
# couldn't locate
# Searching Librivox ID:  116
# couldn't locate
# Searching Librivox ID:  117
# couldn't locate
# Searching Librivox ID:  118
# couldn't locate
# Searching Librivox ID:  119
# Searching Librivox ID:  120
# Searching Librivox ID:  121
# Searching Librivox ID:  122
# Searching Librivox ID:  123
# Searching Librivox ID:  124
# Searching Librivox ID:  125
# couldn't locate
# Searching Librivox ID:  126
# Searching Librivox ID:  127
# Searching Librivox ID:  128
# Searching Librivox ID:  129
# couldn't locate
# Searching Librivox ID:  130
# couldn't locate
# Searching Librivox ID:  131
# Searching Librivox ID:  132
# Searching Librivox ID:  133
# Searching Librivox ID:  134
# Searching Librivox ID:  135
# Searching Librivox ID:  136
# Searching Librivox ID:  137
# Searching Librivox ID:  138
# Searching Librivox ID:  139
# Searching Librivox ID:  140
# Searching Librivox ID:  141
# Searching Librivox ID:  142
# Searching Librivox ID:  143
# Searching Librivox ID:  144
# Searching Librivox ID:  145
# Searching Librivox ID:  146
# Searching Librivox ID:  147
# Searching Librivox ID:  148
# Searching Librivox ID:  149
# Searching Librivox ID:  150
# Searching Librivox ID:  151
# Searching Librivox ID:  152
# Searching Librivox ID:  153
# Searching Librivox ID:  154
# Searching Librivox ID:  155
# Searching Librivox ID:  156
# Searching Librivox ID:  157
# Searching Librivox ID:  158
# Searching Librivox ID:  159
# Searching Librivox ID:  160
# Searching Librivox ID:  161
# Searching Librivox ID:  162
# Searching Librivox ID:  163
# Searching Librivox ID:  164
# Searching Librivox ID:  165
# couldn't locate
# Searching Librivox ID:  166
# Searching Librivox ID:  167
# couldn't locate
# Searching Librivox ID:  168
# Searching Librivox ID:  169
# Searching Librivox ID:  170
# Searching Librivox ID:  171
# Searching Librivox ID:  172
# Searching Librivox ID:  173
# Searching Librivox ID:  174
# Searching Librivox ID:  175
# Searching Librivox ID:  176
# Searching Librivox ID:  177
# Searching Librivox ID:  178
# couldn't locate
# Searching Librivox ID:  179
# Searching Librivox ID:  180
# Searching Librivox ID:  181
# Searching Librivox ID:  182
# Searching Librivox ID:  183
# Searching Librivox ID:  184
# Searching Librivox ID:  185
# couldn't locate
# Searching Librivox ID:  186
# Searching Librivox ID:  187
# Searching Librivox ID:  188
# Searching Librivox ID:  189
# Searching Librivox ID:  190
# couldn't locate
# Searching Librivox ID:  191
# Searching Librivox ID:  192
# Searching Librivox ID:  193
# Searching Librivox ID:  194
# Searching Librivox ID:  195
# Searching Librivox ID:  196
# Searching Librivox ID:  197
# Searching Librivox ID:  198
# Searching Librivox ID:  199
# Searching Librivox ID:  200
# Searching Librivox ID:  201
# Searching Librivox ID:  202
# Searching Librivox ID:  203
# Searching Librivox ID:  204
# Searching Librivox ID:  205
# Searching Librivox ID:  825
# Searching Librivox ID:  826
# Searching Librivox ID:  827
# Searching Librivox ID:  828
# couldn't locate
# Searching Librivox ID:  829
# Searching Librivox ID:  830
# Searching Librivox ID:  831
# couldn't locate
# Searching Librivox ID:  832
# Searching Librivox ID:  833
# couldn't locate
# Searching Librivox ID:  834
# Searching Librivox ID:  835
# couldn't locate
# Searching Librivox ID:  836
# Searching Librivox ID:  837
# couldn't locate
# Searching Librivox ID:  838
# Searching Librivox ID:  839
# Searching Librivox ID:  840
# couldn't locate
# Searching Librivox ID:  841
# couldn't locate
# Searching Librivox ID:  842
# Searching Librivox ID:  843
# couldn't locate
# Searching Librivox ID:  844
# Searching Librivox ID:  845
# Searching Librivox ID:  846
# Searching Librivox ID:  847
# Searching Librivox ID:  848
# Searching Librivox ID:  849
# Searching Librivox ID:  850
# Searching Librivox ID:  851
# Searching Librivox ID:  852
# Searching Librivox ID:  853
# Searching Librivox ID:  854
# Searching Librivox ID:  855
# Searching Librivox ID:  856
# Searching Librivox ID:  857
# Searching Librivox ID:  858
# couldn't locate
# Searching Librivox ID:  859
# Searching Librivox ID:  860
# Searching Librivox ID:  861
# Searching Librivox ID:  862
# Searching Librivox ID:  863
# Searching Librivox ID:  864
# couldn't locate
# Searching Librivox ID:  865
# couldn't locate
# Searching Librivox ID:  866
# Searching Librivox ID:  867
# Searching Librivox ID:  868
# Searching Librivox ID:  869
# Searching Librivox ID:  870
# Searching Librivox ID:  871
# Searching Librivox ID:  872
# Searching Librivox ID:  873
# Searching Librivox ID:  874
# Searching Librivox ID:  875
# Searching Librivox ID:  876
# Searching Librivox ID:  877
# Searching Librivox ID:  878
# Searching Librivox ID:  879
# Searching Librivox ID:  880
# Searching Librivox ID:  881
# Searching Librivox ID:  882
# Searching Librivox ID:  883
# Searching Librivox ID:  884
# Searching Librivox ID:  885
# Searching Librivox ID:  886
# couldn't locate
# Searching Librivox ID:  887
# Searching Librivox ID:  888
# couldn't locate
# Searching Librivox ID:  889
# couldn't locate
# Searching Librivox ID:  890
# Searching Librivox ID:  891
# Searching Librivox ID:  892
# Searching Librivox ID:  893
# Searching Librivox ID:  894
# Searching Librivox ID:  895
# Searching Librivox ID:  896
# Searching Librivox ID:  897
# Searching Librivox ID:  898
# Searching Librivox ID:  899
# Searching Librivox ID:  900
# Searching Librivox ID:  901
# Searching Librivox ID:  902
# Searching Librivox ID:  903
# Searching Librivox ID:  904
# Searching Librivox ID:  905
# couldn't locate
# Searching Librivox ID:  906
# Searching Librivox ID:  907
# Searching Librivox ID:  908
# couldn't locate
# Searching Librivox ID:  909
# Searching Librivox ID:  910
# couldn't locate
# Searching Librivox ID:  911
# Searching Librivox ID:  912
# Searching Librivox ID:  913
# Searching Librivox ID:  914
# Searching Librivox ID:  915
# Searching Librivox ID:  916
# couldn't locate
# Searching Librivox ID:  917
# Searching Librivox ID:  918
# Searching Librivox ID:  919
# Searching Librivox ID:  920
# couldn't locate
# Searching Librivox ID:  921
# Searching Librivox ID:  922
# Searching Librivox ID:  923
# Searching Librivox ID:  924
# Searching Librivox ID:  925
# Searching Librivox ID:  926
# Searching Librivox ID:  927
# couldn't locate
# Searching Librivox ID:  928
# couldn't locate
# Searching Librivox ID:  929
# Searching Librivox ID:  930
# Searching Librivox ID:  931
# Searching Librivox ID:  932
# Searching Librivox ID:  933
# Searching Librivox ID:  934
# Searching Librivox ID:  935
# Searching Librivox ID:  936
# Searching Librivox ID:  937
# Searching Librivox ID:  938
# Searching Librivox ID:  939
# Searching Librivox ID:  940
# Searching Librivox ID:  941
# Searching Librivox ID:  942
# Searching Librivox ID:  943
# couldn't locate
# Searching Librivox ID:  944
# Searching Librivox ID:  945
# Searching Librivox ID:  946
# Searching Librivox ID:  947
# Searching Librivox ID:  948
# couldn't locate
# Searching Librivox ID:  949
# Searching Librivox ID:  950
# Searching Librivox ID:  951
# Searching Librivox ID:  952
# Searching Librivox ID:  953
# couldn't locate
# Searching Librivox ID:  954
# Searching Librivox ID:  955
# couldn't locate
# Searching Librivox ID:  956
# Searching Librivox ID:  957
# Searching Librivox ID:  958
# Searching Librivox ID:  959
# Searching Librivox ID:  960
# Searching Librivox ID:  961
# Searching Librivox ID:  962
# couldn't locate
# Searching Librivox ID:  963
# Searching Librivox ID:  964
# Searching Librivox ID:  965
# Searching Librivox ID:  966
# Searching Librivox ID:  967
# Searching Librivox ID:  968
# Searching Librivox ID:  969
# Searching Librivox ID:  970
# couldn't locate
# Searching Librivox ID:  971
# Searching Librivox ID:  972
# Searching Librivox ID:  973
# couldn't locate
# Searching Librivox ID:  974
# Searching Librivox ID:  975
# Searching Librivox ID:  976
# Searching Librivox ID:  977
# Searching Librivox ID:  978
# Searching Librivox ID:  979
# couldn't locate
# Searching Librivox ID:  980
# Searching Librivox ID:  981
# Searching Librivox ID:  982
# Searching Librivox ID:  983
# couldn't locate
# Searching Librivox ID:  984
# couldn't locate
# Searching Librivox ID:  985
# Searching Librivox ID:  986
# Searching Librivox ID:  987
# Searching Librivox ID:  988
# Searching Librivox ID:  989
# Searching Librivox ID:  990
# Searching Librivox ID:  991
# Searching Librivox ID:  992
# Searching Librivox ID:  993
# Searching Librivox ID:  994
# Searching Librivox ID:  995
# Searching Librivox ID:  996
# Searching Librivox ID:  997
# Searching Librivox ID:  998
# Searching Librivox ID:  999
# Searching Librivox ID:  1000
# Searching Librivox ID:  1001

# %%
        
# Function for removing NonAscii characters
def _removeNonAscii(s):
    return "".join(i for i in s if  int(i)<128)# Function for converting into lower case
def make_lower_case(text):
    return str(text).lower()# Function for removing stop words
def remove_stop_words(text):
    text = text.split()
    stops = set(stopwords.words("english"))
    text = [w for w in text if not w in stops]
    text = " ".join(text)
    return text# Function for removing punctuation
def remove_punctuation(text):
    tokenizer = RegexpTokenizer(r'\w+')
    text = tokenizer.tokenize(text)
    text = " ".join(text)
    return text
#Function for removing the html tags
def remove_html(text):
    html_pattern = re.compile('<.*?>')
    return html_pattern.sub(r'', text)# Applying all the functions in description and storing as a cleaned_desc




executable_path = {'executable_path':'../resources/chromedriver'}
browser = Browser('chrome', **executable_path)
book_objs=[]
for x in range(16000):
    print("Searching Librivox ID: ",x)
    librivox_id_search = f'https://librivox.org/api/feed/audiobooks/?id={x}'
    # librivox_id_search = f'https://librivox.org/api/feed/audiobooks/?id=65'
    try:
            browser.visit(librivox_id_search)
            librivox_id_search_page = browser.html
            soup = BeautifulSoup(librivox_id_search_page, 'html.parser')
            lib_id=soup.find("id").get_text()
            title=soup.find("title").get_text()
            description=soup.find("description").get_text()
            language=soup.find("language").get_text()
            copyright_year=soup.find("copyright_year").get_text()
            lib_url=soup.find('url_librivox').get_text()
            author_fname= soup.find('author').find('first_name').get_text()
            author_lname= soup.find('author').find('last_name').get_text()
            author= author_fname+" "+author_lname
            browser.visit(lib_url)
            book_url_page=browser.html
            soup = BeautifulSoup(book_url_page, 'html.parser')
            genre=soup.find_all('p', class_='book-page-genre')[0].get_text()
            genre_arr=genre.split(":")
            genre=genre_arr[1]
            book_objs.append({"lib_id":lib_id,
                        "title":title,
                        "author":author,
                        "genre":genre,
                        "description":description,
                        "language":language,
                        "copyright_year":copyright_year,
                        "lib_url":lib_url                  
                            })
            book_df = pd.DataFrame(book_objs)
            book_df['cleaned_desc'] = book_df['description'].apply(func = make_lower_case)
# test_book_df['cleaned_desc'] = df.cleaned_desc.apply(func = make_lower_case)
            book_df['cleaned_desc'] = book_df.cleaned_desc.apply(func = remove_stop_words)
            book_df['cleaned_desc'] = book_df.cleaned_desc.apply(func=remove_punctuation)
            book_df['cleaned_desc'] = book_df.cleaned_desc.apply(func=remove_html)
            
            # Matching the language with the dataset and reset the index
            data = book_df.loc[book_df['language'] == language]  
            data.reset_index(level = 0, inplace = True) 
            print('Convert the index into series')
            indices = pd.Series(data.index, index = data['title'])
            # print(indices)
            print("Converting the book title into vectors and used bigram")
            tf = TfidfVectorizer(analyzer='word', ngram_range=(2, 2), min_df = 1, stop_words='english')
            tfidf_matrix = tf.fit_transform(data['cleaned_desc'])
            # print(tfidf_matrix)
            print("Calculating the similarity measures based on Cosine Similarity")
            sg = cosine_similarity(tfidf_matrix, tfidf_matrix)
            # print(indices)    
            print("Get the index corresponding to original_title")       
            idx = indices[title]
            print('Get the pairwise similarity scores') 
            sig = list(enumerate(sg[idx]))
            # print(sig)
            print("Sort the books")
            sig = sorted(sig, key=lambda x: x[1].any(), reverse=True)
            print('Scores of the 5 most similar books') 
            sig = sig[1:6]
            print("Book indicies")
            movie_indices = [i[0] for i in sig]
            print("Top 5 book recommendation")
            rec = data[['title']].iloc[movie_indices]   
            print(rec)
            rec = data[['title']].iloc[movie_indices]
            rec_whole_df = book_df[book_df['title'].isin(rec['title'])]
            # print(rec_whole_df.to_json(orient='records'))
#             rec_whole_df.columns
    except: 
        print("couldn't locate")

# %%
            executable_path = {'executable_path':'../resources/chromedriver'}
            browser2 = Browser('chrome', **executable_path)
    
            librivox_id_search = 'https://librivox.org/api/feed/audiobooks/?id=47'
            browser2.visit(librivox_id_search)
            librivox_id_search_page = browser2.html
            soup = BeautifulSoup(librivox_id_search_page, 'html.parser')
            lib_id=soup.find("id").get_text()
            title=soup.find("title").get_text()
            description=soup.find("description").get_text()
            language=soup.find("language").get_text()
            copyright_year=soup.find("copyright_year").get_text()
            lib_url=soup.find('url_librivox').get_text()
            author_fname= soup.find('author').find('first_name').get_text()
            author_lname= soup.find('author').find('last_name').get_text()
            author= author_fname+" "+author_lname
            browser.visit(lib_url)
            book_url_page=browser.html
            soup = BeautifulSoup(book_url_page, 'html.parser')
            genre=soup.find_all('p', class_='book-page-genre')[0].get_text()
            genre_arr=genre.split(":")
            genre=genre_arr[1]
            book_objs.append({"lib_id":lib_id,
                        "title":title,
                        "author":author,
                        "genre":genre,
                        "description":description,
                        "language":language,
                        "copyright_year":copyright_year,
                        "lib_url":lib_url                  
                            })
            book_df = pd.DataFrame(book_objs)
            book_df['cleaned_desc'] = book_df['description'].apply(func = make_lower_case)
# test_book_df['cleaned_desc'] = df.cleaned_desc.apply(func = make_lower_case)
            book_df['cleaned_desc'] = book_df.cleaned_desc.apply(func = remove_stop_words)
            book_df['cleaned_desc'] = book_df.cleaned_desc.apply(func=remove_punctuation)
            book_df['cleaned_desc'] = book_df.cleaned_desc.apply(func=remove_html)
            # Matching the language with the dataset and reset the index
            data = book_df.loc[book_df['language'] == language]  
            data.reset_index(level = 0, inplace = True) 
            print('Convert the index into series')
            indices = pd.Series(data.index, index = data['title'])
            # print(indices)
            print("Converting the book title into vectors and used bigram")
            tf = TfidfVectorizer(analyzer='word', ngram_range=(2, 2), min_df = 1, stop_words='english')
            tfidf_matrix = tf.fit_transform(data['cleaned_desc'])
            # print(tfidf_matrix)
            print("Calculating the similarity measures based on Cosine Similarity")
            sg = cosine_similarity(tfidf_matrix, tfidf_matrix)
            # print(indices)    
            print("Get the index corresponding to original_title")       
            idx = indices[title]
            print('Get the pairwise similarity scores') 
            sig = list(enumerate(sg[idx]))
            # print(sig)
            print("Sort the books")
            sig = sorted(sig, key=lambda x: x[1].any(), reverse=True)
            print('Scores of the 5 most similar books') 
            sig = sig[1:6]
            print("Book indicies")
            movie_indices = [i[0] for i in sig]
            print("Top 5 book recommendation")
            rec = data[['title']].iloc[movie_indices]   
            print(rec)
            rec = data[['title']].iloc[movie_indices]
            rec_whole_df = book_df[book_df['title'].isin(rec['title'])]
            print(rec_whole_df)

# %%
# Function for removing NonAscii characters
def _removeNonAscii(s):
    return "".join(i for i in s if  int(i)<128)# Function for converting into lower case
def make_lower_case(text):
    return str(text).lower()# Function for removing stop words
def remove_stop_words(text):
    text = text.split()
    stops = set(stopwords.words("english"))
    text = [w for w in text if not w in stops]
    text = " ".join(text)
    return text# Function for removing punctuation
def remove_punctuation(text):
    tokenizer = RegexpTokenizer(r'\w+')
    text = tokenizer.tokenize(text)
    text = " ".join(text)
    return text
#Function for removing the html tags
def remove_html(text):
    html_pattern = re.compile('<.*?>')
    return html_pattern.sub(r'', text)# Applying all the functions in description and storing as a cleaned_desc
book_df['cleaned_desc'] = book_df['description'].apply(func = make_lower_case)
# test_book_df['cleaned_desc'] = df.cleaned_desc.apply(func = make_lower_case)
book_df['cleaned_desc'] = book_df.cleaned_desc.apply(func = remove_stop_words)
book_df['cleaned_desc'] = book_df.cleaned_desc.apply(func=remove_punctuation)
book_df['cleaned_desc'] = book_df.cleaned_desc.apply(func=remove_html)

# %%
title="Count of Monte Cristo"
language="English"

# Matching the language with the dataset and reset the index
data = book_df.loc[book_df['language'] == language]  
data.reset_index(level = 0, inplace = True) 
print('Convert the index into series')
indices = pd.Series(data.index, index = data['title'])
# print(indices)
print("Converting the book title into vectors and used bigram")
tf = TfidfVectorizer(analyzer='word', ngram_range=(2, 2), min_df = 1, stop_words='english')
tfidf_matrix = tf.fit_transform(data['cleaned_desc'])
# print(tfidf_matrix)
print("Calculating the similarity measures based on Cosine Similarity")
sg = cosine_similarity(tfidf_matrix, tfidf_matrix)
# print(indices)    
print("Get the index corresponding to original_title")       
idx = indices[title]
print('Get the pairwise similarity scores') 
sig = list(enumerate(sg[idx]))
# print(sig)
print("Sort the books")
sig = sorted(sig, key=lambda x: x[1].any(), reverse=True)
print('Scores of the 5 most similar books') 
sig = sig[1:6]
print("Book indicies")
movie_indices = [i[0] for i in sig]
print("Top 5 book recommendation")
rec = data[['title']].iloc[movie_indices]   
print(rec)
rec = data[['title']].iloc[movie_indices]
rec_whole_df = book_df[book_df['title'].isin(rec['title'])]
# print(rec_whole_df.to_json(orient='records'))
rec_whole_df.columns

# %%
executable_path = {'executable_path':'../resources/chromedriver'}
browser = Browser('chrome', **executable_path)

static_recs_path="../resources/combined_recommendations_v1.csv"
recs_df=pd.read_csv(static_recs_path)

rec_objs_list=[]

for x in recs_df['book_title']:
    rec_arr = recs_df.loc[recs_df['book_title'] == x]['book_recommendation_urls'].values
    title = x
    print(title)
#     rec_arr=x['book_recommendation_urls']
    pattern=r'(?i)\b((?:[a-z][\w-]+:(?:/{1,3}|[a-z0-9%])|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:\'".,<>?«»“”‘’]))';
    print("matching URLS...")
    match = re.findall(pattern, str(rec_arr))
    # match[1][0]
    rec_urls=[]
    for x in match:
        rec_urls.append(x[0])
    rec_objs=[]
    print("scraping...")
    # Scrape
    for x in rec_urls:
        browser.visit(x)
        search_page = browser.html
        soup = BeautifulSoup(search_page, 'html.parser')
        book_page= soup.find('div', class_="page book-page")
        title=book_page.find('h1').get_text()
        author=book_page.find('p', class_="book-page-author").get_text()
        img_url=book_page.find('div', class_="book-page-book-cover").find('img').get('src')
        rec_objs.append({
            'title':title,
            'author':author,
            'img_url':img_url,
            'page_url':x
        })
        print(title, "done")
        print(rec_objs)
        
    rec_objs_list.append({
                "title":title,
                "rec_objects":rec_objs
            })
    print("appended")
    rec_objs_df=pd.DataFrame(rec_objs_list)
    rec_objs_df.to_csv('rec_obj_list_v1.csv')
    print("written to csv")


print("finished")
print(rec_objs_list)
