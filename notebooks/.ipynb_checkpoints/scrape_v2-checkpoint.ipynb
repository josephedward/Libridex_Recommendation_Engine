# %%
import pandas as pd
from bs4 import BeautifulSoup
import time 
from splinter import Browser
from textblob import TextBlob
import nltk
nltk.download('averaged_perceptron_tagger')
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
import re
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import random
from tqdm import tqdm
from gensim.models import Word2Vec 
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings;
import IPython
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/dev/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
book_df = pd.read_csv("./book_obj_list_v2.csv")

# %%
# Function for removing NonAscii characters
def _removeNonAscii(s):
    return "".join(i for i in s if  int(i)<128)# Function for converting into lower case
def make_lower_case(text):
    return str(text).lower()# Function for removing stop words
def remove_stop_words(text):
    text = text.split()
    stops = set(stopwords.words("english"))
    text = [w for w in text if not w in stops]
    text = " ".join(text)
    return text# Function for removing punctuation
def remove_punctuation(text):
    tokenizer = RegexpTokenizer(r'\w+')
    text = tokenizer.tokenize(text)
    text = " ".join(text)
    return text
#Function for removing the html tags
def remove_html(text):
    html_pattern = re.compile('<.*?>')
    return html_pattern.sub(r'', text)# Applying all the functions in description and storing as a cleaned_desc
def remove_html_2(text):
    cleantext = BeautifulSoup(text, "lxml").text
    return cleantext
book_df['cleaned_desc'] = book_df['description'].apply(func = make_lower_case)
# test_book_df['cleaned_desc'] = df.cleaned_desc.apply(func = make_lower_case)
book_df['cleaned_desc'] = book_df.cleaned_desc.apply(func = remove_stop_words)
book_df['cleaned_desc'] = book_df.cleaned_desc.apply(func=remove_punctuation)
# book_df['cleaned_desc'] = book_df.cleaned_desc.apply(func=remove_html)
book_df['cleaned_desc'] = book_df.cleaned_desc.apply(func=remove_html_2)

# %%
# Function for recommending books based on Book title. It takes book title and genre as an input.def recommend(title, genre):
    
title="Count of Monte Cristo"
language="English"

# book_name=title
try:
# Matching the language with the dataset and reset the index
    data = book_df.loc[book_df['language'] == language]  
    data.reset_index(level = 0, inplace = True) 
    print('Convert the index into series')

    indices = pd.Series(data.index, index = data['title'])
    # print(indices)
    print("Converting the book title into vectors and used bigram")
    tf = TfidfVectorizer(analyzer='word', ngram_range=(2, 2), min_df = 1, stop_words='english')
    tfidf_matrix = tf.fit_transform(data['cleaned_desc'])
    # print(tfidf_matrix)
    print("Calculating the similarity measures based on Cosine Similarity")
    sg = cosine_similarity(tfidf_matrix, tfidf_matrix)
    # print(indices)    
    print("Get the index corresponding to original_title")       
    idx = indices[title]
    print('Get the pairwise similarity scores') 
    sig = list(enumerate(sg[idx]))
    # print(sig)
    print("Sort the books")
    sig = sorted(sig, key=lambda x: x[1].any(), reverse=True)
    print('Scores of the 5 most similar books') 
    sig = sig[1:6]
    print("Book indicies")
    movie_indices = [i[0] for i in sig]
    print("Top 5 book recommendation")
    rec = data[['title']].iloc[movie_indices]   
    print(rec)
    rec = data[['title']].iloc[movie_indices]
    rec_whole_df = book_df[book_df['title'].isin(rec['title'])]
    # print(rec_whole_df.to_json(orient='records'))
    # print(book_df.loc[book_df['title'==book_name]])
    print(title)
    rec_whole_df['lib_url'].to_list()


except MemoryError:
    import IPython
    app = IPython.Application.instance()
    app.kernel.do_shutdown(True)  
    

    # It reads the top 5 recommend book url and print the images
    
# for i in rec['title']:
#     print(i)
#         response = requests.get(i)
#         img = Image.open(BytesIO(response.content))
#         plt.figure()
#         print(plt.imshow(img))
# Out:
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                     title
# 2             Bleak House
# 4   This Side of Paradise
# 9                 Odyssey
# 10          Divine Comedy
# 14      Uncle Tom's Cabin
# Count of Monte Cristo

# %%
rec_whole_df['cleaned_desc'].columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-f9d3e63a8bd8> in <module>
# ----> 1 rec_whole_df['cleaned_desc'].columns
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
language="English"

book_recommendations_list=[]

for x in book_df['title']:
    title=x
    print("Title: ", title)
    # Matching the language with the dataset and reset the index
    try:
       # Matching the language with the dataset and reset the index
        data = book_df.loc[book_df['language'] == language]  
        data.reset_index(level = 0, inplace = True) 
        print('Convert the index into series')
        indices = pd.Series(data.index, index = data['title'])
        # print(indices)
        print("Converting the book title into vectors and used bigram")
        tf = TfidfVectorizer(analyzer='word', ngram_range=(2, 2), min_df = 1, stop_words='english')
        tfidf_matrix = tf.fit_transform(data['cleaned_desc'])
        # print(tfidf_matrix)
        print("Calculating the similarity measures based on Cosine Similarity")
        sg = cosine_similarity(tfidf_matrix, tfidf_matrix)
        # print(indices)    
        print("Get the index corresponding to original_title")       
        idx = indices[title]
        print('Get the pairwise similarity scores') 
        sig = list(enumerate(sg[idx]))
        # print(sig)
        print("Sort the books")
        sig = sorted(sig, key=lambda x: x[1].any(), reverse=True)
        print('Scores of the 5 most similar books') 
        sig = sig[1:6]
        print("Book indicies")
        movie_indices = [i[0] for i in sig]
        print("Top 5 book recommendation")
        rec = data[['title']].iloc[movie_indices]   
        print(rec)
        rec = data[['title']].iloc[movie_indices]
        rec_whole_df = book_df[book_df['title'].isin(rec['title'])]
        # print(rec_whole_df.to_json(orient='records'))
        print(rec_whole_df['lib_url'])
        book_recommendations_list.append({
            "book_title":title,
            "book_recommendation_urls":rec_whole_df['lib_url'].to_list()
        })
        book_rec_df=pd.DataFrame(book_recommendations_list)
        book_rec_df.to_csv("book_recommendations_list_v1.csv")
    except:
        print("exception in running analysis for: ", title)
# Out:
# Title:  Count of Monte Cristo
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                     title
# 2             Bleak House
# 4   This Side of Paradise
# 9                 Odyssey
# 10          Divine Comedy
# 14      Uncle Tom's Cabin
# 2     https://librivox.org/bleak-house-by-charles-di...
# 4     https://librivox.org/this-side-of-paradise-by-...
# 9            https://librivox.org/the-odyssey-by-homer/
# 11    https://librivox.org/the-divine-comedy-by-dant...
# 16    https://librivox.org/uncle-toms-cabin-by-harri...
# Name: lib_url, dtype: object
# Title:  Letters of Two Brides
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                                  title
# 11            Unbeaten Tracks in Japan
# 12                   Canterville Ghost
# 19  Vindication of the Rights of Woman
# 21           Consolation of Philosophy
# 23      Mrs. Caudle's Curtain Lectures
# 12    https://librivox.org/unbeaten-tracks-in-japan-...
# 13    https://librivox.org/the-canterville-ghost-by-...
# 23    https://librivox.org/a-vindication-of-the-righ...
# 25    https://librivox.org/the-consolation-of-philos...
# 27    https://librivox.org/mrs-caudles-curtain-lectu...
# Name: lib_url, dtype: object
# Title:  Bleak House
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                     title
# 2             Bleak House
# 4   This Side of Paradise
# 9                 Odyssey
# 10          Divine Comedy
# 14      Uncle Tom's Cabin
# 2     https://librivox.org/bleak-house-by-charles-di...
# 4     https://librivox.org/this-side-of-paradise-by-...
# 9            https://librivox.org/the-odyssey-by-homer/
# 11    https://librivox.org/the-divine-comedy-by-dant...
# 16    https://librivox.org/uncle-toms-cabin-by-harri...
# Name: lib_url, dtype: object
# Title:  Penguin Island
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                                     title
# 20                      Getting of Wisdom
# 73   Journey to the Interior of the Earth
# 95      Personal Anthology of Shakespeare
# 106                      Northanger Abbey
# 294             Innocence of Father Brown
# 24     https://librivox.org/the-getting-of-wisdom-by-...
# 89     https://librivox.org/a-journey-to-the-interior...
# 116    https://librivox.org/a-personal-anthology-of-s...
# 130    https://librivox.org/northanger-abbey-by-jane-...
# 323    https://librivox.org/the-innocence-of-father-b...
# Name: lib_url, dtype: object
# Title:  This Side of Paradise
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                     title
# 2             Bleak House
# 4   This Side of Paradise
# 9                 Odyssey
# 10          Divine Comedy
# 14      Uncle Tom's Cabin
# 2     https://librivox.org/bleak-house-by-charles-di...
# 4     https://librivox.org/this-side-of-paradise-by-...
# 9            https://librivox.org/the-odyssey-by-homer/
# 11    https://librivox.org/the-divine-comedy-by-dant...
# 16    https://librivox.org/uncle-toms-cabin-by-harri...
# Name: lib_url, dtype: object
# Title:  Secret Garden
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                                  title
# 23      Mrs. Caudle's Curtain Lectures
# 69   Secret Chambers and Hiding Places
# 130   Sadhana, the Realisation of Life
# 146         Ghost Story Collection 001
# 187               Song (Donne version)
# 27     https://librivox.org/mrs-caudles-curtain-lectu...
# 83     https://librivox.org/secret-chambers-and-hidin...
# 155    https://librivox.org/sadhana-by-rabindranath-t...
# 172     https://librivox.org/ghost-story-collection-001/
# 213             https://librivox.org/song-by-john-donne/
# Name: lib_url, dtype: object
# Title:  Twenty Years After
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                                                    title
# 10039  Celebrated Crimes, Vol. 6: Part 2: The Man in ...
# 10809  d'Artagnan Romances, Vol 1: The Three Musketee...
# 10951  d'Artagnan Romances, Vol 2: Twenty Years After...
# 11414  d'Artagnan Romances, Vol 3, Part 1: The Vicomt...
# 11697  d'Artagnan Romances, Vol 3, Part 3: The Man in...
# 11561    https://librivox.org/celebrated-crimes-vol-6-p...
# 12420    https://librivox.org/the-dartagnan-romances-vo...
# 12587    https://librivox.org/the-dartagnan-romances-vo...
# 13125    https://librivox.org/the-dartagnan-romances-vo...
# 13447    https://librivox.org/the-dartagnan-romances-vo...
# Name: lib_url, dtype: object
# Title:  Adventures of Huckleberry Finn
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                           title
# 18             Dream Psychology
# 20            Getting of Wisdom
# 24  Importance of Being Earnest
# 25  Story of a Stuffed Elephant
# 28                     Lord Jim
# 21    https://librivox.org/dream-psychology-by-sigmu...
# 24    https://librivox.org/the-getting-of-wisdom-by-...
# 29    https://librivox.org/the-importance-of-being-e...
# 30    https://librivox.org/the-story-of-a-stuffed-el...
# 33       https://librivox.org/lord-jim-by-joseph-conrad
# Name: lib_url, dtype: object
# Title:  Heart of Darkness
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                                title
# 35                  Three Musketeers
# 48                   Christmas Carol
# 51             International Episode
# 61                  Call of the Wild
# 91  Alice's Adventures in Wonderland
# 40       https://librivox.org/the-three-musketeers-by-a...
# 57       https://librivox.org/a-christmas-carol-by-char...
# 60       https://librivox.org/an-international-episode-...
# 75       https://librivox.org/call-of-the-wild-by-jack-...
# 112      https://librivox.org/alices-adventures-in-wond...
# 12870    https://librivox.org/christmas-carol-by-sara-t...
# 13762    https://librivox.org/a-christmas-carol-by-char...
# Name: lib_url, dtype: object
# Title:  Odyssey
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                     title
# 2             Bleak House
# 4   This Side of Paradise
# 9                 Odyssey
# 10          Divine Comedy
# 14      Uncle Tom's Cabin
# 2     https://librivox.org/bleak-house-by-charles-di...
# 4     https://librivox.org/this-side-of-paradise-by-...
# 9            https://librivox.org/the-odyssey-by-homer/
# 11    https://librivox.org/the-divine-comedy-by-dant...
# 16    https://librivox.org/uncle-toms-cabin-by-harri...
# Name: lib_url, dtype: object
# Title:  Märchen (Index aller Märchen)
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# exception in running analysis for:  Märchen (Index aller Märchen)
# Title:  Divine Comedy
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                     title
# 2             Bleak House
# 4   This Side of Paradise
# 9                 Odyssey
# 10          Divine Comedy
# 14      Uncle Tom's Cabin
# 2     https://librivox.org/bleak-house-by-charles-di...
# 4     https://librivox.org/this-side-of-paradise-by-...
# 9            https://librivox.org/the-odyssey-by-homer/
# 11    https://librivox.org/the-divine-comedy-by-dant...
# 16    https://librivox.org/uncle-toms-cabin-by-harri...
# Name: lib_url, dtype: object
# Title:  Unbeaten Tracks in Japan
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                                  title
# 11            Unbeaten Tracks in Japan
# 19  Vindication of the Rights of Woman
# 21           Consolation of Philosophy
# 23      Mrs. Caudle's Curtain Lectures
# 31      Merry Adventures of Robin Hood
# 12    https://librivox.org/unbeaten-tracks-in-japan-...
# 23    https://librivox.org/a-vindication-of-the-righ...
# 25    https://librivox.org/the-consolation-of-philos...
# 27    https://librivox.org/mrs-caudles-curtain-lectu...
# 36    https://librivox.org/the-merry-adventures-of-r...
# Name: lib_url, dtype: object
# Title:  Canterville Ghost
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                                        title
# 12                         Canterville Ghost
# 44      Around the World in Seventy-Two Days
# 99                     China and the Chinese
# 188                               On Liberty
# 287  Strange Case of Dr. Jekyll and Mr. Hyde
# 13     https://librivox.org/the-canterville-ghost-by-...
# 53     https://librivox.org/around-the-world-in-seven...
# 123    https://librivox.org/china-and-the-chinese-by-...
# 214    https://librivox.org/on-liberty-by-john-stuart...
# 316    https://librivox.org/the-strange-case-of-dr-je...
# Name: lib_url, dtype: object
# Title:  Fábulas de Esopo, Vol. 1
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# exception in running analysis for:  Fábulas de Esopo, Vol. 1
# Title:  Mother Goose in Prose
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                             title
# 102                  Crome Yellow
# 150   Little Wizard Stories of Oz
# 155  Dorothy and the Wizard in Oz
# 190                      Reginald
# 209        Wonderful Wizard of Oz
# 126    https://librivox.org/crome-yellow-by-aldous-hu...
# 176    https://librivox.org/little-wizard-stories-of-...
# 181    https://librivox.org/dorothy-and-the-wizard-in...
# 216               https://librivox.org/reginald-by-saki/
# 236     https://librivox.org/the-wonderful-wizard-of-oz/
# Name: lib_url, dtype: object
# Title:  Uncle Tom's Cabin
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                     title
# 2             Bleak House
# 4   This Side of Paradise
# 9                 Odyssey
# 10          Divine Comedy
# 14      Uncle Tom's Cabin
# 2     https://librivox.org/bleak-house-by-charles-di...
# 4     https://librivox.org/this-side-of-paradise-by-...
# 9            https://librivox.org/the-odyssey-by-homer/
# 11    https://librivox.org/the-divine-comedy-by-dant...
# 16    https://librivox.org/uncle-toms-cabin-by-harri...
# Name: lib_url, dtype: object
# Title:  Truth About Jesus.  Is He a Myth?
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                                 title
# 23     Mrs. Caudle's Curtain Lectures
# 91   Alice's Adventures in Wonderland
# 245                  Jude the Obscure
# 280              Song My Paddle Sings
# 398                       Vanity Fair
# 27     https://librivox.org/mrs-caudles-curtain-lectu...
# 112    https://librivox.org/alices-adventures-in-wond...
# 273    https://librivox.org/jude-the-obscure-by-thoma...
# 309    https://librivox.org/song-my-paddle-sings-by-e...
# 447    https://librivox.org/vanity-fair-by-william-ma...
# Name: lib_url, dtype: object
# Title:  Foolish Dictionary
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                               title
# 33    Poems Every Child Should Know
# 150     Little Wizard Stories of Oz
# 202  Story of the Three Little Pigs
# 205         Bible (WEB) NT 04: John
# 379    Essays in Radical Empiricism
# 38     https://librivox.org/poems-every-child-should-...
# 176    https://librivox.org/little-wizard-stories-of-...
# 229    https://librivox.org/three-little-pigs-by-l-le...
# 232                   https://librivox.org/book-of-john/
# 420    https://librivox.org/essays-in-radical-empiric...
# Name: lib_url, dtype: object
# Title:  Ranald Bannerman's Boyhood
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                                                 title
# 28                                           Lord Jim
# 41  Last of the Mohicans - A Narrative of 1757 (ve...
# 45                                      My Man Jeeves
# 50                        American Indian Fairy Tales
# 52                             Andersen's Fairy Tales
# 33       https://librivox.org/lord-jim-by-joseph-conrad
# 49    https://librivox.org/the-last-of-the-mohicans-...
# 54    https://librivox.org/my-man-jeeves-by-p-g-wode...
# 59    https://librivox.org/american-indian-fairy-tal...
# 61    https://librivox.org/andersens-fairy-tales-by-...
# Name: lib_url, dtype: object
# Title:  Fables de La Fontaine, livre 01
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# exception in running analysis for:  Fables de La Fontaine, livre 01
# Title:  Dream Psychology
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                                                 title
# 18                                   Dream Psychology
# 27   Junior Classics Volume 1: Fairy and Wonder Tales
# 487                                       Book of Tea
# 495                                Gulliver's Travels
# 497                                   Robinson Crusoe
# 21     https://librivox.org/dream-psychology-by-sigmu...
# 32     https://librivox.org/the-junior-classics-vol-1...
# 544    https://librivox.org/the-book-of-tea-by-okakur...
# 554    https://librivox.org/gullivers-travels-by-jona...
# 556    https://librivox.org/robinson-crusoe-by-daniel...
# Name: lib_url, dtype: object
# Title:  Winnetou I
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# exception in running analysis for:  Winnetou I
# Title:  Vindication of the Rights of Woman
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                     title
# 1   Letters of Two Brides
# 2             Bleak House
# 4   This Side of Paradise
# 9                 Odyssey
# 10          Divine Comedy
# 1     https://librivox.org/letters-of-two-brides-by-...
# 2     https://librivox.org/bleak-house-by-charles-di...
# 4     https://librivox.org/this-side-of-paradise-by-...
# 9            https://librivox.org/the-odyssey-by-homer/
# 11    https://librivox.org/the-divine-comedy-by-dant...
# Name: lib_url, dtype: object
# Title:  Getting of Wisdom
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                              title
# 7   Adventures of Huckleberry Finn
# 20               Getting of Wisdom
# 28                        Lord Jim
# 29                        Villette
# 37          Girl of the Limberlost
# 7     https://librivox.org/the-adventures-of-huckleb...
# 24    https://librivox.org/the-getting-of-wisdom-by-...
# 33       https://librivox.org/lord-jim-by-joseph-conrad
# 34    https://librivox.org/villette-by-charlotte-bro...
# 44    https://librivox.org/a-girl-of-the-limberlost-...
# Name: lib_url, dtype: object
# Title:  Consolation of Philosophy
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                     title
# 1   Letters of Two Brides
# 2             Bleak House
# 4   This Side of Paradise
# 9                 Odyssey
# 10          Divine Comedy
# 1     https://librivox.org/letters-of-two-brides-by-...
# 2     https://librivox.org/bleak-house-by-charles-di...
# 4     https://librivox.org/this-side-of-paradise-by-...
# 9            https://librivox.org/the-odyssey-by-homer/
# 11    https://librivox.org/the-divine-comedy-by-dant...
# Name: lib_url, dtype: object
# Title:  Emma
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                            title
# 24   Importance of Being Earnest
# 32           Wives and Daughters
# 40                   Queen Lucia
# 106             Northanger Abbey
# 138          Pride and Prejudice
# 29     https://librivox.org/the-importance-of-being-e...
# 37     https://librivox.org/wives-and-daughters-by-el...
# 47     https://librivox.org/queen-lucia-by-edward-fre...
# 130    https://librivox.org/northanger-abbey-by-jane-...
# 164    https://librivox.org/pride-and-prejudice-by-ja...
# Name: lib_url, dtype: object
# Title:  Mrs. Caudle's Curtain Lectures
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                                  title
# 2                          Bleak House
# 5                        Secret Garden
# 11            Unbeaten Tracks in Japan
# 15   Truth About Jesus.  Is He a Myth?
# 19  Vindication of the Rights of Woman
# 2     https://librivox.org/bleak-house-by-charles-di...
# 5     https://librivox.org/the-secret-garden-by-fran...
# 12    https://librivox.org/unbeaten-tracks-in-japan-...
# 17    https://librivox.org/the-truth-about-jesus-is-...
# 23    https://librivox.org/a-vindication-of-the-righ...
# Name: lib_url, dtype: object
# Title:  Fábulas de Esopo, Vol. 2
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# exception in running analysis for:  Fábulas de Esopo, Vol. 2
# Title:  Importance of Being Earnest
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                             title
# 1           Letters of Two Brides
# 2                     Bleak House
# 4           This Side of Paradise
# 7  Adventures of Huckleberry Finn
# 9                         Odyssey
# 1    https://librivox.org/letters-of-two-brides-by-...
# 2    https://librivox.org/bleak-house-by-charles-di...
# 4    https://librivox.org/this-side-of-paradise-by-...
# 7    https://librivox.org/the-adventures-of-huckleb...
# 9           https://librivox.org/the-odyssey-by-homer/
# Name: lib_url, dtype: object
# Title:  Story of a Stuffed Elephant
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                                      title
# 25             Story of a Stuffed Elephant
# 61                        Call of the Wild
# 242  Five Little Peppers and How They Grew
# 473                            Jungle Book
# 483          At the Back of the North Wind
# 30     https://librivox.org/the-story-of-a-stuffed-el...
# 75     https://librivox.org/call-of-the-wild-by-jack-...
# 270    https://librivox.org/five-little-peppers-and-h...
# 527    https://librivox.org/the-jungle-book-by-rudyar...
# 540    https://librivox.org/at-the-back-of-the-north-...
# Name: lib_url, dtype: object
# Title:  Wind in the Willows
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                         title
# 26        Wind in the Willows
# 45              My Man Jeeves
# 53            Anne of Avonlea
# 97              Old Christmas
# 120  Our Island Story, Part 1
# 31     https://librivox.org/the-wind-in-the-willows-b...
# 54     https://librivox.org/my-man-jeeves-by-p-g-wode...
# 62     https://librivox.org/anne-of-avonlea-by-lucy-m...
# 119    https://librivox.org/old-christmas-by-washingt...
# 145    https://librivox.org/our-island-story-part-1-b...
# Name: lib_url, dtype: object
# Title:  Junior Classics Volume 1: Fairy and Wonder Tales
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                                                 title
# 27   Junior Classics Volume 1: Fairy and Wonder Tales
# 200                                History of Holland
# 247                               Grimms' Fairy Tales
# 255                     Ghost Stories of an Antiquary
# 333                                 Time and the Gods
# 32     https://librivox.org/the-junior-classics-vol-1...
# 227             https://librivox.org/history-of-holland/
# 275    https://librivox.org/fairy-tales-by-the-brothe...
# 283    https://librivox.org/ghost-stories-of-an-antiq...
# 367    https://librivox.org/time-and-the-gods-by-lord...
# Name: lib_url, dtype: object
# Title:  Lord Jim
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                              title
# 7   Adventures of Huckleberry Finn
# 17      Ranald Bannerman's Boyhood
# 20               Getting of Wisdom
# 28                        Lord Jim
# 37          Girl of the Limberlost
# 7     https://librivox.org/the-adventures-of-huckleb...
# 19    https://librivox.org/ranald-bannermans-boyhood...
# 24    https://librivox.org/the-getting-of-wisdom-by-...
# 33       https://librivox.org/lord-jim-by-joseph-conrad
# 44    https://librivox.org/a-girl-of-the-limberlost-...
# Name: lib_url, dtype: object
# Title:  Villette
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                        title
# 29                  Villette
# 35          Three Musketeers
# 74           Little Princess
# 662             Stalky & Co.
# 843  What Katy Did at School
# 34     https://librivox.org/villette-by-charlotte-bro...
# 40     https://librivox.org/the-three-musketeers-by-a...
# 90     https://librivox.org/a-little-princess-by-fran...
# 736    https://librivox.org/stalky-and-co-by-rudyard-...
# 929    https://librivox.org/what-katy-did-at-school-b...
# Name: lib_url, dtype: object
# Title:  Narrative of Arthur Gordon Pym of Nantucket
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                     title
# 2             Bleak House
# 4   This Side of Paradise
# 9                 Odyssey
# 10          Divine Comedy
# 14      Uncle Tom's Cabin
# 2     https://librivox.org/bleak-house-by-charles-di...
# 4     https://librivox.org/this-side-of-paradise-by-...
# 9            https://librivox.org/the-odyssey-by-homer/
# 11    https://librivox.org/the-divine-comedy-by-dant...
# 16    https://librivox.org/uncle-toms-cabin-by-harri...
# Name: lib_url, dtype: object
# Title:  Merry Adventures of Robin Hood
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                     title
# 1   Letters of Two Brides
# 2             Bleak House
# 4   This Side of Paradise
# 9                 Odyssey
# 10          Divine Comedy
# 1     https://librivox.org/letters-of-two-brides-by-...
# 2     https://librivox.org/bleak-house-by-charles-di...
# 4     https://librivox.org/this-side-of-paradise-by-...
# 9            https://librivox.org/the-odyssey-by-homer/
# 11    https://librivox.org/the-divine-comedy-by-dant...
# Name: lib_url, dtype: object
# Title:  Wives and Daughters
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                     title
# 2             Bleak House
# 4   This Side of Paradise
# 9                 Odyssey
# 10          Divine Comedy
# 14      Uncle Tom's Cabin
# 2     https://librivox.org/bleak-house-by-charles-di...
# 4     https://librivox.org/this-side-of-paradise-by-...
# 9            https://librivox.org/the-odyssey-by-homer/
# 11    https://librivox.org/the-divine-comedy-by-dant...
# 16    https://librivox.org/uncle-toms-cabin-by-harri...
# Name: lib_url, dtype: object
# Title:  Poems Every Child Should Know
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                               title
# 33    Poems Every Child Should Know
# 151       Long Poems Collection 001
# 152       Long Poems Collection 002
# 190                        Reginald
# 202  Story of the Three Little Pigs
# 38     https://librivox.org/poems-every-child-should-...
# 177      https://librivox.org/long-poems-collection-001/
# 178      https://librivox.org/long-poems-collection-002/
# 216               https://librivox.org/reginald-by-saki/
# 229    https://librivox.org/three-little-pigs-by-l-le...
# Name: lib_url, dtype: object
# Title:  Art of War
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                     title
# 2             Bleak House
# 4   This Side of Paradise
# 9                 Odyssey
# 10          Divine Comedy
# 14      Uncle Tom's Cabin
# 2     https://librivox.org/bleak-house-by-charles-di...
# 4     https://librivox.org/this-side-of-paradise-by-...
# 9            https://librivox.org/the-odyssey-by-homer/
# 11    https://librivox.org/the-divine-comedy-by-dant...
# 16    https://librivox.org/uncle-toms-cabin-by-harri...
# Name: lib_url, dtype: object
# Title:  Three Musketeers
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                             title
# 1           Letters of Two Brides
# 2                     Bleak House
# 4           This Side of Paradise
# 7  Adventures of Huckleberry Finn
# 8               Heart of Darkness
# 1    https://librivox.org/letters-of-two-brides-by-...
# 2    https://librivox.org/bleak-house-by-charles-di...
# 4    https://librivox.org/this-side-of-paradise-by-...
# 7    https://librivox.org/the-adventures-of-huckleb...
# 8    https://librivox.org/heart-of-darkness-by-jose...
# Name: lib_url, dtype: object
# Title:  Fábulas de Esopo, Vol. 3
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# exception in running analysis for:  Fábulas de Esopo, Vol. 3
# Title:  Bible (LSG, 1910) NT 04: Évangile selon Jean
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# exception in running analysis for:  Bible (LSG, 1910) NT 04: Évangile selon Jean
# Title:  Amateur Cracksman
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                              title
# 141             Psmith in the City
# 191              Red House Mystery
# 196  Adventures of Sherlock Holmes
# 218               Canterbury Tales
# 220                         Hamlet
# 167    https://librivox.org/psmith-in-the-city-by-pg-...
# 217    https://librivox.org/the-red-house-mystery-by-...
# 222    https://librivox.org/the-adventures-of-sherloc...
# 245    https://librivox.org/the-canterbury-tales-by-g...
# 248    https://librivox.org/hamlet-by-william-shakesp...
# Name: lib_url, dtype: object
# Title:  Girl of the Limberlost
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                     title
# 2             Bleak House
# 4   This Side of Paradise
# 9                 Odyssey
# 10          Divine Comedy
# 14      Uncle Tom's Cabin
# 2     https://librivox.org/bleak-house-by-charles-di...
# 4     https://librivox.org/this-side-of-paradise-by-...
# 9            https://librivox.org/the-odyssey-by-homer/
# 11    https://librivox.org/the-divine-comedy-by-dant...
# 16    https://librivox.org/uncle-toms-cabin-by-harri...
# Name: lib_url, dtype: object
# Title:  Rosary
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                                                 title
# 38                                             Rosary
# 40                                        Queen Lucia
# 41  Last of the Mohicans - A Narrative of 1757 (ve...
# 68                                 Anne of the Island
# 80                                                 If
# 45     https://librivox.org/the-rosary-by-florence-lo...
# 47     https://librivox.org/queen-lucia-by-edward-fre...
# 49     https://librivox.org/the-last-of-the-mohicans-...
# 82     https://librivox.org/anne-of-the-island-by-luc...
# 101          https://librivox.org/if-by-rudyard-kipling/
# Name: lib_url, dtype: object
# Title:  Golden mean to 5000 digits
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                    title
# 0  Count of Monte Cristo
# 1  Letters of Two Brides
# 2            Bleak House
# 3         Penguin Island
# 4  This Side of Paradise
# 0    https://librivox.org/the-count-of-monte-cristo...
# 1    https://librivox.org/letters-of-two-brides-by-...
# 2    https://librivox.org/bleak-house-by-charles-di...
# 3    https://librivox.org/penguin-island-by-anatole...
# 4    https://librivox.org/this-side-of-paradise-by-...
# Name: lib_url, dtype: object
# Title:  Queen Lucia
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                              title
# 7   Adventures of Huckleberry Finn
# 22                            Emma
# 23  Mrs. Caudle's Curtain Lectures
# 24     Importance of Being Earnest
# 38                          Rosary
# 7       https://librivox.org/the-adventures-of-huckleb...
# 26         https://librivox.org/emma-by-jane-austen-solo/
# 27      https://librivox.org/mrs-caudles-curtain-lectu...
# 29      https://librivox.org/the-importance-of-being-e...
# 45      https://librivox.org/the-rosary-by-florence-lo...
# 9986          https://librivox.org/emma-by-jane-austen-3/
# Name: lib_url, dtype: object
# Title:  Histoires ou Contes du temps passé avec des moralités
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# exception in running analysis for:  Histoires ou Contes du temps passé avec des moralités
# Title:  Last of the Mohicans - A Narrative of 1757 (version 2)
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                              title
# 2                      Bleak House
# 4            This Side of Paradise
# 7   Adventures of Huckleberry Finn
# 9                          Odyssey
# 10                   Divine Comedy
# 2     https://librivox.org/bleak-house-by-charles-di...
# 4     https://librivox.org/this-side-of-paradise-by-...
# 7     https://librivox.org/the-adventures-of-huckleb...
# 9            https://librivox.org/the-odyssey-by-homer/
# 11    https://librivox.org/the-divine-comedy-by-dant...
# Name: lib_url, dtype: object
# Title:  Jane Eyre
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                                               title
# 396              Life and Adventures of Santa Claus
# 443                           Sense and Sensibility
# 498                         Tenant of Wildfell Hall
# 652   Strange Manuscript Found in a Copper Cylinder
# 1185                                 Life In Mexico
# 445     https://librivox.org/the-life-and-adventures-o...
# 496     https://librivox.org/sense-and-sensibility-by-...
# 557     https://librivox.org/the-tenant-of-wildfell-ha...
# 725     https://librivox.org/a-strange-manuscript-foun...
# 1319    https://librivox.org/life-in-mexico-by-frances...
# Name: lib_url, dtype: object
# Title:  Eclogues
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                                  title
# 7       Adventures of Huckleberry Finn
# 11            Unbeaten Tracks in Japan
# 19  Vindication of the Rights of Woman
# 21           Consolation of Philosophy
# 23      Mrs. Caudle's Curtain Lectures
# 7     https://librivox.org/the-adventures-of-huckleb...
# 12    https://librivox.org/unbeaten-tracks-in-japan-...
# 23    https://librivox.org/a-vindication-of-the-righ...
# 25    https://librivox.org/the-consolation-of-philos...
# 27    https://librivox.org/mrs-caudles-curtain-lectu...
# Name: lib_url, dtype: object
# Title:  Eclogae (dramatic reading)
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# exception in running analysis for:  Eclogae (dramatic reading)
# Title:  Around the World in Seventy-Two Days
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                                  title
# 11            Unbeaten Tracks in Japan
# 12                   Canterville Ghost
# 19  Vindication of the Rights of Woman
# 21           Consolation of Philosophy
# 23      Mrs. Caudle's Curtain Lectures
# 12    https://librivox.org/unbeaten-tracks-in-japan-...
# 13    https://librivox.org/the-canterville-ghost-by-...
# 23    https://librivox.org/a-vindication-of-the-righ...
# 25    https://librivox.org/the-consolation-of-philos...
# 27    https://librivox.org/mrs-caudles-curtain-lectu...
# Name: lib_url, dtype: object
# Title:  My Man Jeeves
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                                  title
# 11            Unbeaten Tracks in Japan
# 17          Ranald Bannerman's Boyhood
# 19  Vindication of the Rights of Woman
# 21           Consolation of Philosophy
# 23      Mrs. Caudle's Curtain Lectures
# 12    https://librivox.org/unbeaten-tracks-in-japan-...
# 19    https://librivox.org/ranald-bannermans-boyhood...
# 23    https://librivox.org/a-vindication-of-the-righ...
# 25    https://librivox.org/the-consolation-of-philos...
# 27    https://librivox.org/mrs-caudles-curtain-lectu...
# Name: lib_url, dtype: object
# Title:  Ballad of John Silver
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                           title
# 24  Importance of Being Earnest
# 35             Three Musketeers
# 43                     Eclogues
# 46        Ballad of John Silver
# 53              Anne of Avonlea
# 29    https://librivox.org/the-importance-of-being-e...
# 40    https://librivox.org/the-three-musketeers-by-a...
# 51    https://librivox.org/the-eclogues-by-publius-v...
# 55    https://librivox.org/a-ballad-of-john-silver-b...
# 62    https://librivox.org/anne-of-avonlea-by-lucy-m...
# Name: lib_url, dtype: object
# Title:  Calendar of Sonnets
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                            title
# 50   American Indian Fairy Tales
# 266                   Purple Cow
# 302             Velveteen Rabbit
# 369        Bible (WEB) 32: Jonah
# 520            God and the State
# 59     https://librivox.org/american-indian-fairy-tal...
# 295    https://librivox.org/the-purple-cow-by-gelett-...
# 331    https://librivox.org/the-velveteen-rabbit-by-m...
# 409              https://librivox.org/the-book-of-jonah/
# 584    https://librivox.org/god-and-the-state-by-mikh...
# Name: lib_url, dtype: object
# Title:  Christmas Carol
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                    title
# 1  Letters of Two Brides
# 2            Bleak House
# 1    https://librivox.org/letters-of-two-brides-by-...
# 2    https://librivox.org/bleak-house-by-charles-di...
# Name: lib_url, dtype: object
# Title:  Connecticut Yankee in King Arthur's Court
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                                          title
# 49   Connecticut Yankee in King Arthur's Court
# 107                 Notes from the Underground
# 192                    Roughing It in the Bush
# 293                       Hunting of the Snark
# 298                    Legend of Sleepy Hollow
# 58     https://librivox.org/a-connecticut-yankee-in-k...
# 131    https://librivox.org/notes-from-the-undergroun...
# 218    https://librivox.org/roughing-it-in-the-bush-b...
# 322    https://librivox.org/the-hunting-of-the-snark-...
# 327    https://librivox.org/the-legend-of-sleepy-holl...
# Name: lib_url, dtype: object
# Title:  American Indian Fairy Tales
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                                         title
# 47                        Calendar of Sonnets
# 50                American Indian Fairy Tales
# 52                     Andersen's Fairy Tales
# 84   Aesop's Fables, Volume 03 (Fables 51-75)
# 85  Aesop's Fables, Volume 04 (Fables 76-100)
# 56     https://librivox.org/a-calendar-of-sonnets-by-...
# 59     https://librivox.org/american-indian-fairy-tal...
# 61     https://librivox.org/andersens-fairy-tales-by-...
# 105    https://librivox.org/aesops-fables-volume-3-fa...
# 106    https://librivox.org/aesops-fables-volume-4-fa...
# Name: lib_url, dtype: object
# Title:  International Episode
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                                title
# 24       Importance of Being Earnest
# 48                   Christmas Carol
# 51             International Episode
# 61                  Call of the Wild
# 91  Alice's Adventures in Wonderland
# 29       https://librivox.org/the-importance-of-being-e...
# 57       https://librivox.org/a-christmas-carol-by-char...
# 60       https://librivox.org/an-international-episode-...
# ...
# exception in running analysis for:  Don Quijote 1
# Title:  Lady Susan (version 2)
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                     title
# 1   Letters of Two Brides
# 2             Bleak House
# 4   This Side of Paradise
# 9                 Odyssey
# 10          Divine Comedy
# 1     https://librivox.org/letters-of-two-brides-by-...
# 2     https://librivox.org/bleak-house-by-charles-di...
# 4     https://librivox.org/this-side-of-paradise-by-...
# 9            https://librivox.org/the-odyssey-by-homer/
# 11    https://librivox.org/the-divine-comedy-by-dant...
# Name: lib_url, dtype: object
# Title:  Kwaidan: Stories and Studies of Strange Things
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                                                   title
# 402      Kwaidan: Stories and Studies of Strange Things
# 594                           Girl Who Sat by the Ashes
# 1694                                  Famous Sea Fights
# 1943                             Biography of a Grizzly
# 1957  History of the Christian Church During the Fir...
# 452     https://librivox.org/kwaidan-stories-and-studi...
# 661     https://librivox.org/the-girl-who-sat-by-the-a...
# 1924    https://librivox.org/famous-sea-fights-by-john...
# 2234     https://librivox.org/the-biography-of-a-grizzly/
# 2257    https://librivox.org/history-of-the-christian-...
# Name: lib_url, dtype: object
# Title:  Prime Numbers
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                    title
# 0  Count of Monte Cristo
# 1  Letters of Two Brides
# 2            Bleak House
# 3         Penguin Island
# 4  This Side of Paradise
# 0    https://librivox.org/the-count-of-monte-cristo...
# 1    https://librivox.org/letters-of-two-brides-by-...
# 2    https://librivox.org/bleak-house-by-charles-di...
# 3    https://librivox.org/penguin-island-by-anatole...
# 4    https://librivox.org/this-side-of-paradise-by-...
# Name: lib_url, dtype: object
# Title:  Essays, First Series
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                                           title
# 1261  Introduction to The Philosophy of History
# 2313                                Hidden Hand
# 4401                                   De Anima
# 6638                          Great Astronomers
# 7339                     Stone Axe Of Burkamukk
# 1403    https://librivox.org/introduction-to-the-philo...
# 2701    https://librivox.org/the-hidden-hand-by-eden-s...
# 5201          https://librivox.org/de-anima-by-aristotle/
# 7736    https://librivox.org/great-astronomers-by-robe...
# 8546    https://librivox.org/the-stone-axe-of-burkamuk...
# Name: lib_url, dtype: object
# Title:  Glugs of Gosh
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                                         title
# 405                             Glugs of Gosh
# 467                             Ideal Husband
# 613  Life And Adventures Of Nicholas Nickleby
# 754                               Howards End
# 760                                Boy's Will
# 455    https://librivox.org/glugs-of-gosh-by-c-j-dennis/
# 520    https://librivox.org/an-ideal-husband-by-oscar...
# 683    https://librivox.org/the-life-and-adventures-o...
# 833      https://librivox.org/howards-end-by-e-m-forster
# 839    https://librivox.org/a-boys-will-by-robert-frost/
# Name: lib_url, dtype: object
# Title:  Imitation of Christ
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                                  title
# 10                       Divine Comedy
# 32                 Wives and Daughters
# 109             O Captain! My Captain!
# 267  Railway Bridge of the Silvery Tay
# 292   History of the Peloponnesian War
# 11      https://librivox.org/the-divine-comedy-by-dant...
# 37      https://librivox.org/wives-and-daughters-by-el...
# 133     https://librivox.org/o-captain-my-captain-by-w...
# 296     https://librivox.org/the-railway-bridge-of-the...
# 321     https://librivox.org/the-history-of-the-pelopo...
# 8513    https://librivox.org/o-captain-my-captain-by-w...
# Name: lib_url, dtype: object
# Title:  Copyright Question
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                                                   title
# 356   Chronicles of Canada Volume 04 - Jesuit Missio...
# 407                                  Copyright Question
# 624                                     Leaves of Grass
# 696                               Twilight of the Idols
# 1090               Short Nonfiction Collection Vol. 005
# 395     https://librivox.org/the-jesuit-missions-a-chr...
# 457          https://librivox.org/the-copyright-question/
# 695     https://librivox.org/leaves-of-grass-by-walt-w...
# 772     https://librivox.org/the-twilight-of-the-idols...
# 1215    https://librivox.org/librivox-short-nonfiction...
# Name: lib_url, dtype: object
# Title:  Short Poetry Collection 019
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                            title
# 55                 Art and Heart
# 109       O Captain! My Captain!
# 116           Spirits in Bondage
# 134  Short Poetry Collection 001
# 135  Short Poetry Collection 002
# 64      https://librivox.org/art-and-heart-by-ella-whe...
# 133     https://librivox.org/o-captain-my-captain-by-w...
# 141     https://librivox.org/spirits-in-bondage-by-cs-...
# 159     https://librivox.org/short-poetry-collection-001/
# 160     https://librivox.org/short-poetry-collection-002/
# 8513    https://librivox.org/o-captain-my-captain-by-w...
# Name: lib_url, dtype: object
# Title:  Oliver Twist
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                     title
# 1   Letters of Two Brides
# 2             Bleak House
# 4   This Side of Paradise
# 9                 Odyssey
# 10          Divine Comedy
# 1     https://librivox.org/letters-of-two-brides-by-...
# 2     https://librivox.org/bleak-house-by-charles-di...
# 4     https://librivox.org/this-side-of-paradise-by-...
# 9            https://librivox.org/the-odyssey-by-homer/
# 11    https://librivox.org/the-divine-comedy-by-dant...
# Name: lib_url, dtype: object
# Title:  Story of the Treasure Seekers
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                                     title
# 220                                Hamlet
# 221                         Twelfth Night
# 222                   Pirates of Penzance
# 397  Buccaneers and Pirates of Our Coasts
# 410         Story of the Treasure Seekers
# 248    https://librivox.org/hamlet-by-william-shakesp...
# 249    https://librivox.org/twelfth-night-by-william-...
# 250    https://librivox.org/the-pirates-of-penzance-b...
# 446    https://librivox.org/buccaneers-and-the-pirate...
# 460    https://librivox.org/the-story-of-the-treasure...
# Name: lib_url, dtype: object
# Title:  Ideal Bartender
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                                  title
# 11            Unbeaten Tracks in Japan
# 19  Vindication of the Rights of Woman
# 21           Consolation of Philosophy
# 23      Mrs. Caudle's Curtain Lectures
# 31      Merry Adventures of Robin Hood
# 12    https://librivox.org/unbeaten-tracks-in-japan-...
# 23    https://librivox.org/a-vindication-of-the-righ...
# 25    https://librivox.org/the-consolation-of-philos...
# 27    https://librivox.org/mrs-caudles-curtain-lectu...
# 36    https://librivox.org/the-merry-adventures-of-r...
# Name: lib_url, dtype: object
# Title:  New-England Boy's Song About Thanksgiving Day
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                        title
# 55             Art and Heart
# 64             Vagabond Song
# 70        Death Be Not Proud
# 76  Noiseless Patient Spider
# 78        I Do Not Love Thee
# 64    https://librivox.org/art-and-heart-by-ella-whe...
# 78    https://librivox.org/a-vagabond-song-by-bliss-...
# 84    https://librivox.org/death-be-not-proud-by-joh...
# 93    https://librivox.org/a-noiseless-patient-spide...
# 99    https://librivox.org/i-do-not-love-thee-by-car...
# Name: lib_url, dtype: object
# Title:  Price of Love
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                                      title
# 413                          Price of Love
# 599                Love Among the Chickens
# 661                       Room with a View
# 730  Man of Property (Forsyte Saga Vol. 1)
# 832      In Chancery (Forsyte Saga Vol. 2)
# 463    https://librivox.org/the-price-of-love-by-arno...
# 666    https://librivox.org/love-among-the-chickens-b...
# 735    https://librivox.org/a-room-with-a-view-by-em-...
# 807    https://librivox.org/man-of-property-by-john-g...
# 918    https://librivox.org/in-chancery-by-john-galsw...
# Name: lib_url, dtype: object
# Title:  Devil's Dictionary
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                                             title
# 69              Secret Chambers and Hiding Places
# 130              Sadhana, the Realisation of Life
# 137  Present at a Hanging and Other Ghost Stories
# 146                    Ghost Story Collection 001
# 147               Short Story Collection Vol. 006
# 83     https://librivox.org/secret-chambers-and-hidin...
# 155    https://librivox.org/sadhana-by-rabindranath-t...
# 163    https://librivox.org/present-at-a-hanging-by-a...
# 172     https://librivox.org/ghost-story-collection-001/
# 173     https://librivox.org/short-story-collection-006/
# Name: lib_url, dtype: object
# Title:  唐诗三百首 卷二  Three Hundred Tang Poems, Volume 2
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# exception in running analysis for:  唐诗三百首 卷二  Three Hundred Tang Poems, Volume 2
# Title:  Just So Stories
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                                   title
# 396  Life and Adventures of Santa Claus
# 415                     Just So Stories
# 473                         Jungle Book
# 517                          Master Key
# 547                 Rewards and Fairies
# 445    https://librivox.org/the-life-and-adventures-o...
# 466    https://librivox.org/just-so-stories-by-rudyar...
# 527    https://librivox.org/the-jungle-book-by-rudyar...
# 580    https://librivox.org/the-master-key-by-l-frank...
# 612    https://librivox.org/rewards-and-fairies-by-ru...
# Name: lib_url, dtype: object
# Title:  Life in the Clearings Versus the Bush
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                             title
# 1           Letters of Two Brides
# 2                     Bleak House
# 4           This Side of Paradise
# 5                   Secret Garden
# 7  Adventures of Huckleberry Finn
# 1    https://librivox.org/letters-of-two-brides-by-...
# 2    https://librivox.org/bleak-house-by-charles-di...
# 4    https://librivox.org/this-side-of-paradise-by-...
# 5    https://librivox.org/the-secret-garden-by-fran...
# 7    https://librivox.org/the-adventures-of-huckleb...
# Name: lib_url, dtype: object
# Title:  Paradise Lost
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
# Get the index corresponding to original_title
# Get the pairwise similarity scores
# Sort the books
# Scores of the 5 most similar books
# Book indicies
# Top 5 book recommendation
#                                  title
# 11            Unbeaten Tracks in Japan
# 19  Vindication of the Rights of Woman
# 21           Consolation of Philosophy
# 23      Mrs. Caudle's Curtain Lectures
# 31      Merry Adventures of Robin Hood
# 12    https://librivox.org/unbeaten-tracks-in-japan-...
# 23    https://librivox.org/a-vindication-of-the-righ...
# 25    https://librivox.org/the-consolation-of-philos...
# 27    https://librivox.org/mrs-caudles-curtain-lectu...
# 36    https://librivox.org/the-merry-adventures-of-r...
# Name: lib_url, dtype: object
# Title:  Cornhuskers
# Convert the index into series
# Converting the book title into vectors and used bigram
# Calculating the similarity measures based on Cosine Similarity
